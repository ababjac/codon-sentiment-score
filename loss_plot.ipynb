# %%
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModel, TFAutoModelForSequenceClassification
from bertviz import model_view, head_view
from alibi.explainers import IntegratedGradients
import json
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2023-06-09 04:36:51.170826: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-09 04:36:51.681180: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-09 04:36:58.173621: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
import torch
map_location=torch.device('cpu')

# %%
# read the json file
with open('./models/codonBERT_binary_reg_ecoli-pre-frozen/checkpoint-4150/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_reg_ecoli-nopre/checkpoint-4150/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_reg_ecoli-nopre-frozen/checkpoint-4150/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_reg_ecoli-nopre-norm/checkpoint-4150/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_binary_reg_ecoli-pre-frozen-norm/checkpoint-16600/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_binary_reg_ecoli-pre-norm2/checkpoint-16600/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_multi_reg_ecoli-pre-norm2/checkpoint-16600/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_reg_yeasts288c-nopre-frozen/checkpoint-5700/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_reg_yeasts288c-nopre/checkpoint-5700/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_binary_reg_yeasts288c-pre-frozen-norm/checkpoint-22800/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_binary_reg_yeasts288c-pre-frozen-norm2/checkpoint-22800/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_binary_reg_yeasts288c-pre-norm2/checkpoint-22700/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_multi_reg_yeasts288c-pre-norm2/checkpoint-22700/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_reg_atha-nopre-frozen/checkpoint-7350/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_reg_atha-nopre/checkpoint-7350/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_binary_reg_atha-pre-frozen-norm/checkpoint-23079/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_binary_reg_atha-pre-norm2/checkpoint-29400/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_multi_reg_atha-pre-norm2/checkpoint-29400/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT_binary_reg_celegan-pre-norm2/checkpoint-28912/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT-binary-large_1/checkpoint-127330/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
#sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# read the json file
with open('./models/codonBERT-multi-large_1/checkpoint-127330/trainer_state.json', 'r') as f:
    data = json.load(f)

# create a pandas dataframe from the log_history
df = pd.DataFrame(data['log_history'])
#print(df.columns)

# plot the data using seaborn
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x='epoch', y='loss', data=df)
#sns.lineplot(x='epoch', y='eval_loss', data=df)

# epochs = df['epoch']
# losses = df['loss']

# ax.set_xlim([0, max(epochs)])
# ax.set_ylim([0, max(losses) + 0.01])
plt.title('Training Loss over Epochs For ESM2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()
